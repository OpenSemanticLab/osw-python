# %% [markdown]
# ## HttpRequest Test
# dependency: pip install requests

# %%
# request from quantitykind test URI length
import requests
URL = 'http://qudt.org/vocab/quantitykind/Length'

req = requests.Request('GET', URL)
r = req.prepare()
print(r)
s = requests.Session()
res = s.send(r)
# Out:
# <PreparedRequest [GET]>

# %%
#response ok
s.headers
# Out:
# {'User-Agent': 'python-requests/2.25.1', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
#r.content
#r.text
#content must be parsed from text/turtle to json
res
# Out:
# <Response [200]>

# %%
# html fetch
#

# %%
import requests
r = requests.get('https://api.github.com/events')
r.json()
# Out:
# [{'id': '20701201574',
#   'type': 'PushEvent',
#   'actor': {'id': 540511,
#    'login': 'greglandrum',
#    'display_login': 'greglandrum',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/greglandrum',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/540511?'},
#   'repo': {'id': 10009991,
#    'name': 'rdkit/rdkit',
#    'url': 'https://api.github.com/repos/rdkit/rdkit'},
#   'payload': {'push_id': 9326851714,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '6894225df3547cef6d868804c635a6d52aec738c',
#    'before': '27f711a6585e17c0c2882f6d7ea054a1f7a860eb',
#    'commits': [{'sha': '6894225df3547cef6d868804c635a6d52aec738c',
#      'author': {'email': 'greg.landrum@gmail.com', 'name': 'Greg Landrum'},
#      'message': 'first pass at trying an update (#5083)\n\n* first pass at trying an update\r\n\r\n* cleanup',
#      'distinct': True,
# ...

# %%
import requests
import bs4 as bs
URL = 'http://qudt.org/vocab/quantitykind/Length.html'
r = requests.get(URL)
div_id = "div-lm-export-json-quantitykind_Length"
#r.text
soup = bs.BeautifulSoup(r.text,'lxml')
supa = soup.find('ons-list-item',attrs={'id' : div_id})

# %%
import requests
from pyquery import PyQuery as pq
import json
URL = 'http://qudt.org/vocab/quantitykind/Length.html'
r = requests.get(URL)
div_id = "div-lm-export-json-quantitykind_Length"
#r.text

d = pq(r.text)
div = d('#' + div_id);
text = div.text()
if '"properties":[' in text:
    print("malformed json, try fix)
    text = text.replace('"properties":[', '"properties":{')
    text = text.
print(div.text())
json.loads(div.text())
json
# Out:
# {"resource":"Length" ,"qname":"quantitykind:Length" ,"uri":"http:\/\/qudt.org\/vocab\/quantitykind\/Length" ,"properties":["applicable unit":"unit:ANGSTROM" ,"applicable unit":"unit:AU" ,"applicable unit":"unit:BTU_IT-PER-LB_F" ,"applicable unit":"unit:CH" ,"applicable unit":"unit:CentiM" ,"applicable unit":"unit:DecaM" ,"applicable unit":"unit:DeciM" ,"applicable unit":"unit:FATH" ,"applicable unit":"unit:FM" ,"applicable unit":"unit:FT" ,"applicable unit":"unit:FT_US" ,"applicable unit":"unit:FUR" ,"applicable unit":"unit:FUR_Long" ,"applicable unit":"unit:FemtoM" ,"applicable unit":"unit:GAUGE_FR" ,"applicable unit":"unit:HectoM" ,"applicable unit":"unit:IN" ,"applicable unit":"unit:KiloM" ,"applicable unit":"unit:LY" ,"applicable unit":"unit:M" ,"applicable unit":"unit:MI" ,"applicable unit":"unit:MI_N" ,"applicable unit":"unit:MI_US" ,"applicable unit":"unit:MicroIN" ,"applicable unit":"unit:MicroM" ,"applicable unit":"unit:MilLength" ,"applicable unit":"unit:MilliIN" ,"applicab
# ...
